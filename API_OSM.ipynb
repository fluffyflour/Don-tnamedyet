# %%
from time import sleep
from tqdm import tqdm

# %%
import numpy as np
import pandas as pd
import requests

# %%
tqdm.pandas()

# %%
def to_district(address: str, city: str, district_cache):
    """
    Определяет район и координаты по адресу через OSM Nominatim
    Возвращает dict: {district, lat, lon}
    """

    if not isinstance(address, str) or not address.strip():
        return {
            "district": "Некорректный адрес",
            "lat": None,
            "lon": None
        }

    if not isinstance(city, str) or not city.strip():
        return {
            "district": "Некорректный город",
            "lat": None,
            "lon": None
        }

    url = "https://nominatim.openstreetmap.org/search"

    if city not in district_cache:
        district_cache[city] = {}

    if address in district_cache[city]:
        return district_cache[city][address]

    clean_address = address.replace("корп.", "").replace("корп", "").strip()

    params = {
        "street": clean_address,
        "city": city,
        "state": city,
        "country": "Россия",
        "countrycodes": "ru",
        "format": "json",
        "addressdetails": 1,
        "limit": 1
    }

    headers = {
        "User-Agent": "RealEstateDistrictFetcher/1.0 (klvalopatin@edu.hse.ru)",
        "Accept-Language": "ru"
    }

    last_error = None
    for _ in range(3):
        try:
            response = requests.get(url, params=params, headers=headers, timeout=10)
            response.raise_for_status()
            data = response.json()
            break
        except Exception as e:
            last_error = e
            sleep(1)
    else:
        result = {
            "district": f"Ошибка запроса: {last_error}",
            "lat": None,
            "lon": None
        }
        district_cache[city][address] = result
        return result

    sleep(0.1)

    if not data:
    
        result = {
            "district": "Адрес не найден",
            "lat": None,
            "lon": None
        }
        district_cache[city][address] = result
        return result

    item = data[0]
    address_info = item.get("address", {})

    if address_info.get("country_code") != "ru" or city not in item.get("display_name", ""):
        result = {
            "district": "Неверный город или страна",
            "lat": None,
            "lon": None
        }
        district_cache[city][address] = result
        return result

    district = (
        address_info.get("city_district") or
        address_info.get("district") or
        address_info.get("borough") or
        address_info.get("municipality") or
        address_info.get("suburb") or
        address_info.get("neighbourhood") or
        address_info.get("quarter") or
        "Район не найден"
    )

    result = {
        "district": district,
        "lat": float(item["lat"]),
        "lon": float(item["lon"])
    }

    district_cache[city][address] = result
    return result

# %%
to_district(
    "Конструктора Гуськова, 14 ст2",
    "Москва",
    district_cache
)
# Out:
# {'district': 'Адрес не найден', 'lat': None, 'lon': None}

# %%
estate_msk = pd.read_csv('data/estate_msk.csv')
estate_spb = pd.read_csv('data/estate_spb.csv')

# %%
cities = {"msk" : "Москва", "spb" : "Санкт-Петербург"}

# %%
estate_turple = [
    estate_msk,
    estate_spb
]

# %%
estate_msk
# Out:
#       rent, rub/month                    full_address    city  \
# 0             1500000          Пречистенка, 19/11 ст2  Москва
# 1             1197919                      Таежная, 1  Москва
# 2              274809            Дмитровка Б., 32 ст4  Москва
# 3              386458                 Шумкина, 20 ст1  Москва
# 4               68125                 Шумкина, 20 ст1  Москва
# ...               ...                             ...     ...
# 7692          1500000          Краснопролетарская, 36  Москва
# 7693          1176000     Пресненская набережная, 10с  Москва
# 7694          2000000  Пресненская набережная, 10 ст2  Москва
# 7695           300003       Братиславская, 18 корп. 1  Москва
# 7696          1200000               Пятницкая, 30 ст1  Москва
#
#       price_per_sqm, rub/month  square, m^2                        type  \
# 0                        13636          110     Универсальное помещение
# 1                         1917          625     Универсальное помещение
# 2                         4084           67     Универсальное помещение
# 3                         1459          265     Универсальное помещение
# 4                         2084           32     Универсальное помещение
# ...                        ...          ...                         ...
# 7692                      3968          378  Помещение под бар/ресторан
# 7693                      6461          182  Помещение под бар/ресторан
# 7694                      4819          415  Помещение под бар/ресторан
# 7695                      2041          147  Помещение под бар/ресторан
# 7696                      4000          300  Помещение под бар/ресторан
#
#                                                  url
# 0     https://msk.n1.ru/view/114210381/?open_card_kn
# 1     https://msk.n1.ru/view/115999047/?open_card_kn
# 2     https://msk.n1.ru/view/116261376/?open_card_kn
# 3     https://msk.n1.ru/view/116011103/?open_card_kn
# 4     https://msk.n1.ru/view/115777113/?open_card_kn
# ...                                              ...
# 7692  https://msk.n1.ru/view/109731158/?open_card_kn
# 7693  https://msk.n1.ru/view/111002230/?open_card_kn
# 7694  https://msk.n1.ru/view/109683444/?open_card_kn
# 7695  https://msk.n1.ru/view/112349375/?open_card_kn
# 7696  https://msk.n1.ru/view/112067957/?open_card_kn
#
# [7697 rows x 7 columns]

# %%
district_cache = {}

# %%
for estate in estate_turple:
    estate['OSM_address'] = estate['full_address'] + ', ' + estate['city'] + ', Россия'
    estate["address_info"] = estate.progress_apply(
        lambda x: to_district(x['full_address'], x['city'], district_cache),
        axis=1
    )
# Out:
# 100%|██████████| 7697/7697 [58:39<00:00,  2.19it/s]
# 100%|██████████| 1730/1730 [17:08<00:00,  1.68it/s]

# %%
# Проверяем значение ключа "district" в словаре address_info
estate_msk[
    (estate_msk["address_info"].apply(lambda x: x.get("district")) == 'Адрес не найден') |
    (estate_msk["address_info"].apply(lambda x: x.get("district")) == 'Район не найден')
]
# Out:
#       rent, rub/month                          full_address    city  \
# 0             1500000                Пречистенка, 19/11 ст2  Москва
# 2              274809                  Дмитровка Б., 32 ст4  Москва
# 5              320100          Павелецкий 2-й проезд, 5 ст1  Москва
# 6              293601               Мира проспект, 102 ст17  Москва
# 11             800000               Масловка Верхн., 20 ст1  Москва
# ...               ...                                   ...     ...
# 7662           990000                     Мневники Нижн., 9  Москва
# 7671           600000                 Земляной Вал, 50а ст3  Москва
# 7674           649000            Огородный проезд, 16/1 ст6  Москва
# 7678           135000                   пос. Коммунарка, 14  Москва
# 7682           299000  Волгоградский проспект, 32/5 корп. 4  Москва
#
#       price_per_sqm, rub/month  square, m^2                        type  \
# 0                        13636          110     Универсальное помещение
# 2                         4084           67     Универсальное помещение
# 5                         3000          106     Универсальное помещение
# 6                         2667          110     Универсальное помещение
# 11                        2817          283     Универсальное помещение
# ...                        ...          ...                         ...
# 7662                      4977          198  Помещение под бар/ресторан
# 7671                      4123          145  Помещение под бар/ресторан
# 7674                      4013          161  Помещение под бар/ресторан
# 7678                      2020           66  Помещение под бар/ресторан
# 7682                      2718          110  Помещение под бар/ресторан
#
#                                                  url  \
# 0     https://msk.n1.ru/view/114210381/?open_card_kn
# 2     https://msk.n1.ru/view/116261376/?open_card_kn
# 5     https://msk.n1.ru/view/115502574/?open_card_kn
# 6     https://msk.n1.ru/view/114858057/?open_card_kn
# 11    https://msk.n1.ru/view/111240795/?open_card_kn
# ...                                              ...
# 7662  https://msk.n1.ru/view/112711743/?open_card_kn
# 7671  https://msk.n1.ru/view/115312443/?open_card_kn
# 7674  https://msk.n1.ru/view/115306316/?open_card_kn
# 7678  https://msk.n1.ru/view/114593131/?open_card_kn
# 7682  https://msk.n1.ru/view/116004778/?open_card_kn
#
#                                             OSM_address  \
# 0                Пречистенка, 19/11 ст2, Москва, Россия
# 2                  Дмитровка Б., 32 ст4, Москва, Россия
# 5          Павелецкий 2-й проезд, 5 ст1, Москва, Россия
# 6               Мира проспект, 102 ст17, Москва, Россия
# 11              Масловка Верхн., 20 ст1, Москва, Россия
# ...                                                 ...
# 7662                  Мневники Нижн., 9, Москва, Россия
# 7671              Земляной Вал, 50а ст3, Москва, Россия
# 7674         Огородный проезд, 16/1 ст6, Москва, Россия
# 7678                пос. Коммунарка, 14, Москва, Россия
# 7682  Волгоградский проспект, 32/5 корп. 4, Москва, ...
#
#                                            address_info
# 0     {'district': 'Адрес не найден', 'lat': None, '...
# 2     {'district': 'Адрес не найден', 'lat': None, '...
# 5     {'district': 'Адрес не найден', 'lat': None, '...
# 6     {'district': 'Адрес не найден', 'lat': None, '...
# 11    {'district': 'Адрес не найден', 'lat': None, '...
# ...                                                 ...
# 7662  {'district': 'Адрес не найден', 'lat': None, '...
# 7671  {'district': 'Адрес не найден', 'lat': None, '...
# 7674  {'district': 'Адрес не найден', 'lat': None, '...
# 7678  {'district': 'Адрес не найден', 'lat': None, '...
# 7682  {'district': 'Адрес не найден', 'lat': None, '...
#
# [1810 rows x 9 columns]

# %%
estate_cities = pd.concat([
    estate_msk,
    estate_spb
])

# %%
def to_normAdress(address: str):
    return address.split(',')[0]

# %%
mask = (estate_cities["address_info"].apply(lambda x: x.get("district")) == 'Адрес не найден')

estate_cities.loc[mask, "address_info"] = estate_cities.loc[mask].progress_apply(
    lambda x: to_district(to_normAdress(x["full_address"]), x["city"], district_cache),
    axis=1
)
# Out:
# 100%|██████████| 1746/1746 [08:03<00:00,  3.61it/s]

# %%
estate_cities[
    (estate_cities["address_info"].apply(lambda x: x.get("district")) == 'Адрес не найден') |
    (estate_cities["address_info"].apply(lambda x: x.get("district")) == 'Район не найден')
]
# Out:
#       rent, rub/month                                   full_address  \
# 2              274809                           Дмитровка Б., 32 ст4
# 11             800000                        Масловка Верхн., 20 ст1
# 14             358800             проезд улицашоссепр-дпр-д-й, 4 ст4
# 18              87600             проезд улицашоссепр-дпр-д-й, 4 ст4
# 20             175350             Летчика Грицевца (п Внуковское), 5
# ...               ...                                            ...
# 1664           182400                      проспект Старорусский, 12
# 1694           299300  проспект Средний Васильевского острова, 14/45
# 1696           139077                                   Заречная, 54
# 1704          1424000                 Витебский проспект, 99 корп. 1
# 1707           350000                                   Школьная, 14
#
#                  city  price_per_sqm, rub/month  square, m^2  \
# 2              Москва                      4084           67
# 11             Москва                      2817          283
# 14             Москва                      1560          230
# 18             Москва                      2400           36
# 20             Москва                      1500          116
# ...               ...                       ...          ...
# 1664  Санкт-Петербург                      1500          121
# 1694  Санкт-Петербург                      1088          275
# 1696  Санкт-Петербург                      1530           90
# 1704  Санкт-Петербург                      2000          712
# 1707  Санкт-Петербург                      1805          193
#
#                             type  \
# 2        Универсальное помещение
# 11       Универсальное помещение
# 14       Универсальное помещение
# 18       Универсальное помещение
# 20       Универсальное помещение
# ...                          ...
# 1664  Помещение под бар/ресторан
# 1694  Помещение под бар/ресторан
# 1696  Помещение под бар/ресторан
# 1704  Помещение под бар/ресторан
# 1707  Помещение под бар/ресторан
#
#                                                  url  \
# 2     https://msk.n1.ru/view/116261376/?open_card_kn
# 11    https://msk.n1.ru/view/111240795/?open_card_kn
# 14    https://msk.n1.ru/view/114562535/?open_card_kn
# 18    https://msk.n1.ru/view/114547323/?open_card_kn
# 20    https://msk.n1.ru/view/113087033/?open_card_kn
# ...                                              ...
# 1664  https://spb.n1.ru/view/116105509/?open_card_kn
# 1694  https://spb.n1.ru/view/115734209/?open_card_kn
# 1696  https://spb.n1.ru/view/113624912/?open_card_kn
# 1704  https://spb.n1.ru/view/110466463/?open_card_kn
# 1707  https://spb.n1.ru/view/116045159/?open_card_kn
#
#                                             OSM_address  \
# 2                  Дмитровка Б., 32 ст4, Москва, Россия
# 11              Масловка Верхн., 20 ст1, Москва, Россия
# 14    проезд улицашоссепр-дпр-д-й, 4 ст4, Москва, Ро...
# 18    проезд улицашоссепр-дпр-д-й, 4 ст4, Москва, Ро...
# 20    Летчика Грицевца (п Внуковское), 5, Москва, Ро...
# ...                                                 ...
# 1664  проспект Старорусский, 12, Санкт-Петербург, Ро...
# 1694  проспект Средний Васильевского острова, 14/45,...
# 1696              Заречная, 54, Санкт-Петербург, Россия
# 1704  Витебский проспект, 99 корп. 1, Санкт-Петербур...
# 1707              Школьная, 14, Санкт-Петербург, Россия
#
#                                            address_info
# 2     {'district': 'Район не найден', 'lat': 55.1728...
# 11    {'district': 'Адрес не найден', 'lat': None, '...
# 14    {'district': 'Адрес не найден', 'lat': None, '...
# 18    {'district': 'Адрес не найден', 'lat': None, '...
# 20    {'district': 'Адрес не найден', 'lat': None, '...
# ...                                                 ...
# 1664  {'district': 'Район не найден', 'lat': 59.8066...
# 1694  {'district': 'Адрес не найден', 'lat': None, '...
# 1696  {'district': 'Район не найден', 'lat': 60.0838...
# 1704  {'district': 'Район не найден', 'lat': 59.8146...
# 1707  {'district': 'Район не найден', 'lat': 59.8116...
#
# [981 rows x 9 columns]

# %%
estate_cities["district"] = estate_cities["address_info"].apply(
    lambda x: x.get("district") if isinstance(x, dict) else None
)
estate_cities["lat"] = estate_cities["address_info"].apply(
    lambda x: x.get("lat") if isinstance(x, dict) else None
)
estate_cities["lon"] = estate_cities["address_info"].apply(
    lambda x: x.get("lon") if isinstance(x, dict) else None
)

# %%
estate_cities = estate_cities.reset_index(drop=True)

# %%
estate_cities.to_csv("data/estate_cities.csv", index=False)

# %%
estate_cities
# Out:
#       rent, rub/month                     full_address             city  \
# 0             1500000           Пречистенка, 19/11 ст2           Москва
# 1             1197919                       Таежная, 1           Москва
# 2              274809             Дмитровка Б., 32 ст4           Москва
# 3              386458                  Шумкина, 20 ст1           Москва
# 4               68125                  Шумкина, 20 ст1           Москва
# ...               ...                              ...              ...
# 9422           139000  Московский проспект, 72 корп. 2  Санкт-Петербург
# 9423           961538          Энергетиков проспект, 6  Санкт-Петербург
# 9424           110000             Заозерная, 3 корп. 3  Санкт-Петербург
# 9425           518960             Заречная, 52 корп. 1  Санкт-Петербург
# 9426           540000         11-я Красноармейская, 18  Санкт-Петербург
#
#       price_per_sqm, rub/month  square, m^2                        type  \
# 0                        13636          110     Универсальное помещение
# 1                         1917          625     Универсальное помещение
# 2                         4084           67     Универсальное помещение
# 3                         1459          265     Универсальное помещение
# 4                         2084           32     Универсальное помещение
# ...                        ...          ...                         ...
# 9422                      2249           61  Помещение под бар/ресторан
# 9423                      3083          311  Помещение под бар/ресторан
# 9424                      2444           45  Помещение под бар/ресторан
# 9425                      2600          199  Помещение под бар/ресторан
# 9426                      2000          270  Помещение под бар/ресторан
#
#                                                  url  \
# 0     https://msk.n1.ru/view/114210381/?open_card_kn
# 1     https://msk.n1.ru/view/115999047/?open_card_kn
# 2     https://msk.n1.ru/view/116261376/?open_card_kn
# 3     https://msk.n1.ru/view/116011103/?open_card_kn
# 4     https://msk.n1.ru/view/115777113/?open_card_kn
# ...                                              ...
# 9422  https://spb.n1.ru/view/106961445/?open_card_kn
# 9423  https://spb.n1.ru/view/110365219/?open_card_kn
# 9424  https://spb.n1.ru/view/112083708/?open_card_kn
# 9425  https://spb.n1.ru/view/113137877/?open_card_kn
# 9426  https://spb.n1.ru/view/109075138/?open_card_kn
#
#                                             OSM_address  \
# 0                Пречистенка, 19/11 ст2, Москва, Россия
# 1                            Таежная, 1, Москва, Россия
# 2                  Дмитровка Б., 32 ст4, Москва, Россия
# 3                       Шумкина, 20 ст1, Москва, Россия
# 4                       Шумкина, 20 ст1, Москва, Россия
# ...                                                 ...
# 9422  Московский проспект, 72 корп. 2, Санкт-Петербу...
# 9423   Энергетиков проспект, 6, Санкт-Петербург, Россия
# 9424      Заозерная, 3 корп. 3, Санкт-Петербург, Россия
# 9425      Заречная, 52 корп. 1, Санкт-Петербург, Россия
# 9426  11-я Красноармейская, 18, Санкт-Петербург, Россия
#
#                                            address_info  \
# 0     {'district': 'район Хамовники', 'lat': 55.7430...
# 1     {'district': 'Лосиноостровский район', 'lat': ...
# 2     {'district': 'Район не найден', 'lat': 55.1728...
# 3     {'district': 'район Сокольники', 'lat': 55.789...
# 4     {'district': 'район Сокольники', 'lat': 55.789...
# ...                                                 ...
# 9422  {'district': 'округ Измайловское', 'lat': 59.9...
# 9423  {'district': 'округ Большая Охта', 'lat': 59.9...
# 9424  {'district': 'округ Московская застава', 'lat'...
# 9425  {'district': 'Торфяное', 'lat': 60.082999, 'lo...
# 9426  {'district': 'Разлив', 'lat': 60.0908677, 'lon...
#
#                       district        lat        lon
# 0              район Хамовники  55.743015  37.596967
# 1       Лосиноостровский район  55.881107  37.700736
# 2              Район не найден  55.172889  37.122824
# 3             район Сокольники  55.789422  37.666981
# 4             район Сокольники  55.789422  37.666981
# ...                        ...        ...        ...
# 9422        округ Измайловское  59.902811  30.318498
# 9423        округ Большая Охта  59.955832  30.432095
# 9424  округ Московская застава  59.906229  30.324407
# 9425                  Торфяное  60.082999  30.342624
# 9426                    Разлив  60.090868  29.977639
#
# [9427 rows x 12 columns]

# %%
mask = (estate_cities['city'] == 'Санкт-Петербург') & (estate_cities['district'] == 'Адрес не найден')
estate_cities.loc[mask, :].shape
# Out:
# (55, 12)
