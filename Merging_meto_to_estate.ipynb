# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_metroes = pd.read_csv("data/api_metro_stations.csv")
estate_cities = pd.read_csv("data/estate_cities.csv")

# %%
df_metroes
# Out:
#        color                              full_name                 id  \
# 0    #E90101                       Москва, Прокшино  70030076182844294
# 1    #E90101                       Москва, Ольховая  70030076182844297
# 2    #E90101                 Москва, Новомосковская  70030076182844300
# 3    #ACBFE1                Москва, Бунинская аллея   4504385606388666
# 4    #ACBFE1       Москва, Бульвар Адмирала Ушакова   4504385606386967
# ..       ...                                    ...                ...
# 446  #E90101       Санкт-Петербург, Политехническая   5348810536517986
# 447  #0064AF  Санкт-Петербург, Проспект Просвещения   5348810536521400
# 448  #0064AF                Санкт-Петербург, Озерки   5348810536521399
# 449  #E90101  Санкт-Петербург, Гражданский проспект   5348810536521406
# 450  #0064AF                Санкт-Петербург, Парнас   5348810536518754
#
#                          name route_type subtype     type  point.lat  \
# 0                    Прокшино      metro   metro  station  55.586458
# 1                    Ольховая      metro   metro  station  55.569063
# 2              Новомосковская      metro   metro  station  55.559999
# 3             Бунинская аллея      metro   metro  station  55.537976
# 4    Бульвар Адмирала Ушакова      metro   metro  station  55.545264
# ..                        ...        ...     ...      ...        ...
# 446           Политехническая      metro   metro  station  60.008889
# 447      Проспект Просвещения      metro   metro  station  60.051381
# 448                    Озерки      metro   metro  station  60.037105
# 449      Гражданский проспект      metro   metro  station  60.034910
# 450                    Парнас      metro   metro  station  60.066931
#
#      point.lon             city
# 0    37.433136           Москва
# 1    37.458993           Москва
# 2    37.468689           Москва
# 3    37.515831           Москва
# 4    37.542472           Москва
# ..         ...              ...
# 446  30.370917  Санкт-Петербург
# 447  30.332672  Санкт-Петербург
# 448  30.321569  Санкт-Петербург
# 449  30.418230  Санкт-Петербург
# 450  30.333950  Санкт-Петербург
#
# [451 rows x 10 columns]

# %%
estate_cities
# Out:
#       rent, rub/month                     full_address             city  \
# 0             1500000           Пречистенка, 19/11 ст2           Москва
# 1             1197919                       Таежная, 1           Москва
# 2              274809             Дмитровка Б., 32 ст4           Москва
# 3              386458                  Шумкина, 20 ст1           Москва
# 4               68125                  Шумкина, 20 ст1           Москва
# ...               ...                              ...              ...
# 9422           139000  Московский проспект, 72 корп. 2  Санкт-Петербург
# 9423           961538          Энергетиков проспект, 6  Санкт-Петербург
# 9424           110000             Заозерная, 3 корп. 3  Санкт-Петербург
# 9425           518960             Заречная, 52 корп. 1  Санкт-Петербург
# 9426           540000         11-я Красноармейская, 18  Санкт-Петербург
#
#       price_per_sqm, rub/month  square, m^2                        type  \
# 0                        13636          110     Универсальное помещение
# 1                         1917          625     Универсальное помещение
# 2                         4084           67     Универсальное помещение
# 3                         1459          265     Универсальное помещение
# 4                         2084           32     Универсальное помещение
# ...                        ...          ...                         ...
# 9422                      2249           61  Помещение под бар/ресторан
# 9423                      3083          311  Помещение под бар/ресторан
# 9424                      2444           45  Помещение под бар/ресторан
# 9425                      2600          199  Помещение под бар/ресторан
# 9426                      2000          270  Помещение под бар/ресторан
#
#                                                  url  \
# 0     https://msk.n1.ru/view/114210381/?open_card_kn
# 1     https://msk.n1.ru/view/115999047/?open_card_kn
# 2     https://msk.n1.ru/view/116261376/?open_card_kn
# 3     https://msk.n1.ru/view/116011103/?open_card_kn
# 4     https://msk.n1.ru/view/115777113/?open_card_kn
# ...                                              ...
# 9422  https://spb.n1.ru/view/106961445/?open_card_kn
# 9423  https://spb.n1.ru/view/110365219/?open_card_kn
# 9424  https://spb.n1.ru/view/112083708/?open_card_kn
# 9425  https://spb.n1.ru/view/113137877/?open_card_kn
# 9426  https://spb.n1.ru/view/109075138/?open_card_kn
#
#                                             OSM_address  \
# 0                Пречистенка, 19/11 ст2, Москва, Россия
# 1                            Таежная, 1, Москва, Россия
# 2                  Дмитровка Б., 32 ст4, Москва, Россия
# 3                       Шумкина, 20 ст1, Москва, Россия
# 4                       Шумкина, 20 ст1, Москва, Россия
# ...                                                 ...
# 9422  Московский проспект, 72 корп. 2, Санкт-Петербу...
# 9423   Энергетиков проспект, 6, Санкт-Петербург, Россия
# 9424      Заозерная, 3 корп. 3, Санкт-Петербург, Россия
# 9425      Заречная, 52 корп. 1, Санкт-Петербург, Россия
# 9426  11-я Красноармейская, 18, Санкт-Петербург, Россия
#
#                                            address_info  \
# 0     {'district': 'район Хамовники', 'lat': 55.7430...
# 1     {'district': 'Лосиноостровский район', 'lat': ...
# 2     {'district': 'Район не найден', 'lat': 55.1728...
# 3     {'district': 'район Сокольники', 'lat': 55.789...
# 4     {'district': 'район Сокольники', 'lat': 55.789...
# ...                                                 ...
# 9422  {'district': 'округ Измайловское', 'lat': 59.9...
# 9423  {'district': 'округ Большая Охта', 'lat': 59.9...
# 9424  {'district': 'округ Московская застава', 'lat'...
# 9425  {'district': 'Торфяное', 'lat': 60.082999, 'lo...
# 9426  {'district': 'Разлив', 'lat': 60.0908677, 'lon...
#
#                       district        lat        lon
# 0              район Хамовники  55.743015  37.596967
# 1       Лосиноостровский район  55.881107  37.700736
# 2              Район не найден  55.172889  37.122824
# 3             район Сокольники  55.789422  37.666981
# 4             район Сокольники  55.789422  37.666981
# ...                        ...        ...        ...
# 9422        округ Измайловское  59.902811  30.318498
# 9423        округ Большая Охта  59.955832  30.432095
# 9424  округ Московская застава  59.906229  30.324407
# 9425                  Торфяное  60.082999  30.342624
# 9426                    Разлив  60.090868  29.977639
#
# [9427 rows x 12 columns]

# %% [markdown]
# Функция для нахождения расстояние по координатам (на вход коорд. метро и коорд. помещений)

# %% [markdown]
# $d = 2R \cdot \arcsin\left(
# \sqrt{
# \sin^2\left(\frac{\varphi_2 - \varphi_1}{2}\right)
# +
# \cos(\varphi_1)\cos(\varphi_2)\sin^2\left(\frac{\lambda_2 - \lambda_1}{2}\right)
# }
# \right)
# $

# %%
def haversine(lat1, lon1, lat2, lon2):
    R = 6371
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])

    dlat = lat2 - lat1
    dlon = lon2 - lon1
    
    a = np.sin(dlat / 2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2) **2 
    return  2 * R * np.arcsin(np.sqrt(a))

# %%
def find_nearest_metro(place_lat, place_lon, df_metroes):
    distances = haversine(
        place_lat,
        place_lon,
        df_metroes['point.lat'].values,
        df_metroes['point.lon'].values
    )
    
    idx_min = distances.argmin()
    return pd.Series({
        'nearest_metro' : df_metroes.iloc[idx_min]['full_name'],
        'distance_km': distances[idx_min]
    })

# %%
df_metroes
# Out:
#        color                              full_name                 id  \
# 0    #E90101                       Москва, Прокшино  70030076182844294
# 1    #E90101                       Москва, Ольховая  70030076182844297
# 2    #E90101                 Москва, Новомосковская  70030076182844300
# 3    #ACBFE1                Москва, Бунинская аллея   4504385606388666
# 4    #ACBFE1       Москва, Бульвар Адмирала Ушакова   4504385606386967
# ..       ...                                    ...                ...
# 446  #E90101       Санкт-Петербург, Политехническая   5348810536517986
# 447  #0064AF  Санкт-Петербург, Проспект Просвещения   5348810536521400
# 448  #0064AF                Санкт-Петербург, Озерки   5348810536521399
# 449  #E90101  Санкт-Петербург, Гражданский проспект   5348810536521406
# 450  #0064AF                Санкт-Петербург, Парнас   5348810536518754
#
#                          name route_type subtype     type  point.lat  \
# 0                    Прокшино      metro   metro  station  55.586458
# 1                    Ольховая      metro   metro  station  55.569063
# 2              Новомосковская      metro   metro  station  55.559999
# 3             Бунинская аллея      metro   metro  station  55.537976
# 4    Бульвар Адмирала Ушакова      metro   metro  station  55.545264
# ..                        ...        ...     ...      ...        ...
# 446           Политехническая      metro   metro  station  60.008889
# 447      Проспект Просвещения      metro   metro  station  60.051381
# 448                    Озерки      metro   metro  station  60.037105
# 449      Гражданский проспект      metro   metro  station  60.034910
# 450                    Парнас      metro   metro  station  60.066931
#
#      point.lon             city
# 0    37.433136           Москва
# 1    37.458993           Москва
# 2    37.468689           Москва
# 3    37.515831           Москва
# 4    37.542472           Москва
# ..         ...              ...
# 446  30.370917  Санкт-Петербург
# 447  30.332672  Санкт-Петербург
# 448  30.321569  Санкт-Петербург
# 449  30.418230  Санкт-Петербург
# 450  30.333950  Санкт-Петербург
#
# [451 rows x 10 columns]

# %%
df_metroes.loc[:, ]
# Out:
#        color                              full_name                 id  \
# 0    #E90101                       Москва, Прокшино  70030076182844294
# 1    #E90101                       Москва, Ольховая  70030076182844297
# 2    #E90101                 Москва, Новомосковская  70030076182844300
# 3    #ACBFE1                Москва, Бунинская аллея   4504385606388666
# 4    #ACBFE1       Москва, Бульвар Адмирала Ушакова   4504385606386967
# ..       ...                                    ...                ...
# 446  #E90101       Санкт-Петербург, Политехническая   5348810536517986
# 447  #0064AF  Санкт-Петербург, Проспект Просвещения   5348810536521400
# 448  #0064AF                Санкт-Петербург, Озерки   5348810536521399
# 449  #E90101  Санкт-Петербург, Гражданский проспект   5348810536521406
# 450  #0064AF                Санкт-Петербург, Парнас   5348810536518754
#
#                          name route_type subtype     type  point.lat  \
# 0                    Прокшино      metro   metro  station  55.586458
# 1                    Ольховая      metro   metro  station  55.569063
# 2              Новомосковская      metro   metro  station  55.559999
# 3             Бунинская аллея      metro   metro  station  55.537976
# 4    Бульвар Адмирала Ушакова      metro   metro  station  55.545264
# ..                        ...        ...     ...      ...        ...
# 446           Политехническая      metro   metro  station  60.008889
# 447      Проспект Просвещения      metro   metro  station  60.051381
# 448                    Озерки      metro   metro  station  60.037105
# 449      Гражданский проспект      metro   metro  station  60.034910
# 450                    Парнас      metro   metro  station  60.066931
#
#      point.lon             city
# 0    37.433136           Москва
# 1    37.458993           Москва
# 2    37.468689           Москва
# 3    37.515831           Москва
# 4    37.542472           Москва
# ..         ...              ...
# 446  30.370917  Санкт-Петербург
# 447  30.332672  Санкт-Петербург
# 448  30.321569  Санкт-Петербург
# 449  30.418230  Санкт-Петербург
# 450  30.333950  Санкт-Петербург
#
# [451 rows x 10 columns]

# %%
estate_cities[['nearest_metro', 'distance_km']] = estate_cities.apply(
    lambda row : find_nearest_metro(row['lat'], row['lon'], df_metroes),
    axis = 1
)

# %%
estate_cities.loc[estate_cities['district'] == 'Адрес не найден']
# Out:
#       rent, rub/month                                   full_address  \
# 11             800000                        Масловка Верхн., 20 ст1
# 14             358800             проезд улицашоссепр-дпр-д-й, 4 ст4
# 18              87600             проезд улицашоссепр-дпр-д-й, 4 ст4
# 20             175350             Летчика Грицевца (п Внуковское), 5
# 21             596100             Летчика Ульянина (п Внуковское), 4
# ...               ...                                            ...
# 9254           248810       проспект Малый Васильевского острова, 88
# 9285           600000  проспект Средний Васильевского острова, 99/18
# 9294           240000                      3-й (Горелово) проезд, 36
# 9314           110000                              Вадима Шефнера, 4
# 9391           299300  проспект Средний Васильевского острова, 14/45
#
#                  city  price_per_sqm, rub/month  square, m^2  \
# 11             Москва                      2817          283
# 14             Москва                      1560          230
# 18             Москва                      2400           36
# 20             Москва                      1500          116
# 21             Москва                      2500          238
# ...               ...                       ...          ...
# 9254  Санкт-Петербург                      2764           90
# 9285  Санкт-Петербург                      1643          365
# 9294  Санкт-Петербург                      2448           98
# 9314  Санкт-Петербург                      1271           86
# 9391  Санкт-Петербург                      1088          275
#
#                             type  \
# 11       Универсальное помещение
# 14       Универсальное помещение
# 18       Универсальное помещение
# 20       Универсальное помещение
# 21       Универсальное помещение
# ...                          ...
# 9254            Торговая площадь
# 9285            Торговая площадь
# 9294  Помещение под бар/ресторан
# 9314  Помещение под бар/ресторан
# 9391  Помещение под бар/ресторан
#
#                                                  url  \
# 11    https://msk.n1.ru/view/111240795/?open_card_kn
# 14    https://msk.n1.ru/view/114562535/?open_card_kn
# 18    https://msk.n1.ru/view/114547323/?open_card_kn
# 20    https://msk.n1.ru/view/113087033/?open_card_kn
# 21    https://msk.n1.ru/view/113803399/?open_card_kn
# ...                                              ...
# 9254  https://spb.n1.ru/view/115347994/?open_card_kn
# 9285  https://spb.n1.ru/view/114958706/?open_card_kn
# 9294  https://spb.n1.ru/view/109073691/?open_card_kn
# 9314  https://spb.n1.ru/view/112638857/?open_card_kn
# 9391  https://spb.n1.ru/view/115734209/?open_card_kn
#
#                                             OSM_address  \
# 11              Масловка Верхн., 20 ст1, Москва, Россия
# 14    проезд улицашоссепр-дпр-д-й, 4 ст4, Москва, Ро...
# 18    проезд улицашоссепр-дпр-д-й, 4 ст4, Москва, Ро...
# 20    Летчика Грицевца (п Внуковское), 5, Москва, Ро...
# 21    Летчика Ульянина (п Внуковское), 4, Москва, Ро...
# ...                                                 ...
# 9254  проспект Малый Васильевского острова, 88, Санк...
# 9285  проспект Средний Васильевского острова, 99/18,...
# 9294  3-й (Горелово) проезд, 36, Санкт-Петербург, Ро...
# 9314         Вадима Шефнера, 4, Санкт-Петербург, Россия
# 9391  проспект Средний Васильевского острова, 14/45,...
#
#                                            address_info         district  lat  \
# 11    {'district': 'Адрес не найден', 'lat': None, '...  Адрес не найден  NaN
# 14    {'district': 'Адрес не найден', 'lat': None, '...  Адрес не найден  NaN
# 18    {'district': 'Адрес не найден', 'lat': None, '...  Адрес не найден  NaN
# 20    {'district': 'Адрес не найден', 'lat': None, '...  Адрес не найден  NaN
# 21    {'district': 'Адрес не найден', 'lat': None, '...  Адрес не найден  NaN
# ...                                                 ...              ...  ...
# 9254  {'district': 'Адрес не найден', 'lat': None, '...  Адрес не найден  NaN
# 9285  {'district': 'Адрес не найден', 'lat': None, '...  Адрес не найден  NaN
# 9294  {'district': 'Адрес не найден', 'lat': None, '...  Адрес не найден  NaN
# 9314  {'district': 'Адрес не найден', 'lat': None, '...  Адрес не найден  NaN
# 9391  {'district': 'Адрес не найден', 'lat': None, '...  Адрес не найден  NaN
#
#       lon     nearest_metro  distance_km
# 11    NaN  Москва, Прокшино          NaN
# 14    NaN  Москва, Прокшино          NaN
# 18    NaN  Москва, Прокшино          NaN
# 20    NaN  Москва, Прокшино          NaN
# 21    NaN  Москва, Прокшино          NaN
# ...   ...               ...          ...
# 9254  NaN  Москва, Прокшино          NaN
# 9285  NaN  Москва, Прокшино          NaN
# 9294  NaN  Москва, Прокшино          NaN
# 9314  NaN  Москва, Прокшино          NaN
# 9391  NaN  Москва, Прокшино          NaN
#
# [715 rows x 14 columns]

# %%
estate_cities[['lat', 'lon']] = estate_cities[['lat', 'lon']].fillna("Координаты не найдены")
estate_cities['distance_km'] = estate_cities['distance_km'].fillna('Недостаточно данных')

# %%
estate_cities['nearest_metro'] = np.where(
    estate_cities['distance_km'] == 'Недостаточно данных',
    'Недостаточно данных',
    estate_cities['nearest_metro']
)

# %%
estate_cities
# Out:
#       rent, rub/month                     full_address             city  \
# 0             1500000           Пречистенка, 19/11 ст2           Москва
# 1             1197919                       Таежная, 1           Москва
# 2              274809             Дмитровка Б., 32 ст4           Москва
# 3              386458                  Шумкина, 20 ст1           Москва
# 4               68125                  Шумкина, 20 ст1           Москва
# ...               ...                              ...              ...
# 9422           139000  Московский проспект, 72 корп. 2  Санкт-Петербург
# 9423           961538          Энергетиков проспект, 6  Санкт-Петербург
# 9424           110000             Заозерная, 3 корп. 3  Санкт-Петербург
# 9425           518960             Заречная, 52 корп. 1  Санкт-Петербург
# 9426           540000         11-я Красноармейская, 18  Санкт-Петербург
#
#       price_per_sqm, rub/month  square, m^2                        type  \
# 0                        13636          110     Универсальное помещение
# 1                         1917          625     Универсальное помещение
# 2                         4084           67     Универсальное помещение
# 3                         1459          265     Универсальное помещение
# 4                         2084           32     Универсальное помещение
# ...                        ...          ...                         ...
# 9422                      2249           61  Помещение под бар/ресторан
# 9423                      3083          311  Помещение под бар/ресторан
# 9424                      2444           45  Помещение под бар/ресторан
# 9425                      2600          199  Помещение под бар/ресторан
# 9426                      2000          270  Помещение под бар/ресторан
#
#                                                  url  \
# 0     https://msk.n1.ru/view/114210381/?open_card_kn
# 1     https://msk.n1.ru/view/115999047/?open_card_kn
# 2     https://msk.n1.ru/view/116261376/?open_card_kn
# 3     https://msk.n1.ru/view/116011103/?open_card_kn
# 4     https://msk.n1.ru/view/115777113/?open_card_kn
# ...                                              ...
# 9422  https://spb.n1.ru/view/106961445/?open_card_kn
# 9423  https://spb.n1.ru/view/110365219/?open_card_kn
# 9424  https://spb.n1.ru/view/112083708/?open_card_kn
# 9425  https://spb.n1.ru/view/113137877/?open_card_kn
# 9426  https://spb.n1.ru/view/109075138/?open_card_kn
#
#                                             OSM_address  \
# 0                Пречистенка, 19/11 ст2, Москва, Россия
# 1                            Таежная, 1, Москва, Россия
# 2                  Дмитровка Б., 32 ст4, Москва, Россия
# 3                       Шумкина, 20 ст1, Москва, Россия
# 4                       Шумкина, 20 ст1, Москва, Россия
# ...                                                 ...
# 9422  Московский проспект, 72 корп. 2, Санкт-Петербу...
# 9423   Энергетиков проспект, 6, Санкт-Петербург, Россия
# 9424      Заозерная, 3 корп. 3, Санкт-Петербург, Россия
# 9425      Заречная, 52 корп. 1, Санкт-Петербург, Россия
# 9426  11-я Красноармейская, 18, Санкт-Петербург, Россия
#
#                                            address_info  \
# 0     {'district': 'район Хамовники', 'lat': 55.7430...
# 1     {'district': 'Лосиноостровский район', 'lat': ...
# 2     {'district': 'Район не найден', 'lat': 55.1728...
# 3     {'district': 'район Сокольники', 'lat': 55.789...
# 4     {'district': 'район Сокольники', 'lat': 55.789...
# ...                                                 ...
# 9422  {'district': 'округ Измайловское', 'lat': 59.9...
# 9423  {'district': 'округ Большая Охта', 'lat': 59.9...
# 9424  {'district': 'округ Московская застава', 'lat'...
# 9425  {'district': 'Торфяное', 'lat': 60.082999, 'lo...
# 9426  {'district': 'Разлив', 'lat': 60.0908677, 'lon...
#
#                       district        lat        lon  \
# 0              район Хамовники  55.743015  37.596967
# 1       Лосиноостровский район  55.881107  37.700736
# 2              Район не найден  55.172889  37.122824
# 3             район Сокольники  55.789422  37.666981
# 4             район Сокольники  55.789422  37.666981
# ...                        ...        ...        ...
# 9422        округ Измайловское  59.902811  30.318498
# 9423        округ Большая Охта  59.955832  30.432095
# 9424  округ Московская застава  59.906229  30.324407
# 9425                  Торфяное  60.082999  30.342624
# 9426                    Разлив  60.090868  29.977639
#
#                                nearest_metro distance_km
# 0                      Москва, Кропоткинская    0.498615
# 1                         Москва, Медведково    2.532474
# 2                    Москва, Бунинская аллея   47.593815
# 3                           Москва, Митьково    0.481996
# 4                           Москва, Митьково    0.481996
# ...                                      ...         ...
# 9422  Санкт-Петербург, Фрунзенская (закрыта)    0.383607
# 9423              Санкт-Петербург, Ладожская    2.639591
# 9424  Санкт-Петербург, Фрунзенская (закрыта)    0.377055
# 9425                 Санкт-Петербург, Парнас    1.850339
# 9426                Санкт-Петербург, Беговая   16.946271
#
# [9427 rows x 14 columns]

# %%
estate_cities.to_csv("data/estate_cities_withMetroes.csv")

# %%
estate_cities_withMetroes = pd.read_csv('data/estate_cities_withMetroes.csv')

# %%
msk_withMetro = estate_cities_withMetroes.loc[estate_cities_withMetroes['city'] == 'Москва']
spb_withMetro = estate_cities_withMetroes.loc[estate_cities_withMetroes['city'] == 'Санкт-Петербург']

# %%
msk_withMetro
# Out:
#       Unnamed: 0  rent, rub/month                    full_address    city  \
# 0              0          1500000          Пречистенка, 19/11 ст2  Москва
# 1              1          1197919                      Таежная, 1  Москва
# 2              2           274809            Дмитровка Б., 32 ст4  Москва
# 3              3           386458                 Шумкина, 20 ст1  Москва
# 4              4            68125                 Шумкина, 20 ст1  Москва
# ...          ...              ...                             ...     ...
# 7692        7692          1500000          Краснопролетарская, 36  Москва
# 7693        7693          1176000     Пресненская набережная, 10с  Москва
# 7694        7694          2000000  Пресненская набережная, 10 ст2  Москва
# 7695        7695           300003       Братиславская, 18 корп. 1  Москва
# 7696        7696          1200000               Пятницкая, 30 ст1  Москва
#
#       price_per_sqm, rub/month  square, m^2                        type  \
# 0                        13636          110     Универсальное помещение
# 1                         1917          625     Универсальное помещение
# 2                         4084           67     Универсальное помещение
# 3                         1459          265     Универсальное помещение
# 4                         2084           32     Универсальное помещение
# ...                        ...          ...                         ...
# 7692                      3968          378  Помещение под бар/ресторан
# 7693                      6461          182  Помещение под бар/ресторан
# 7694                      4819          415  Помещение под бар/ресторан
# 7695                      2041          147  Помещение под бар/ресторан
# 7696                      4000          300  Помещение под бар/ресторан
#
#                                                  url  \
# 0     https://msk.n1.ru/view/114210381/?open_card_kn
# 1     https://msk.n1.ru/view/115999047/?open_card_kn
# 2     https://msk.n1.ru/view/116261376/?open_card_kn
# 3     https://msk.n1.ru/view/116011103/?open_card_kn
# 4     https://msk.n1.ru/view/115777113/?open_card_kn
# ...                                              ...
# 7692  https://msk.n1.ru/view/109731158/?open_card_kn
# 7693  https://msk.n1.ru/view/111002230/?open_card_kn
# 7694  https://msk.n1.ru/view/109683444/?open_card_kn
# 7695  https://msk.n1.ru/view/112349375/?open_card_kn
# 7696  https://msk.n1.ru/view/112067957/?open_card_kn
#
#                                          OSM_address  \
# 0             Пречистенка, 19/11 ст2, Москва, Россия
# 1                         Таежная, 1, Москва, Россия
# 2               Дмитровка Б., 32 ст4, Москва, Россия
# 3                    Шумкина, 20 ст1, Москва, Россия
# 4                    Шумкина, 20 ст1, Москва, Россия
# ...                                              ...
# 7692          Краснопролетарская, 36, Москва, Россия
# 7693     Пресненская набережная, 10с, Москва, Россия
# 7694  Пресненская набережная, 10 ст2, Москва, Россия
# 7695       Братиславская, 18 корп. 1, Москва, Россия
# 7696               Пятницкая, 30 ст1, Москва, Россия
#
#                                            address_info  \
# 0     {'district': 'район Хамовники', 'lat': 55.7430...
# 1     {'district': 'Лосиноостровский район', 'lat': ...
# 2     {'district': 'Район не найден', 'lat': 55.1728...
# 3     {'district': 'район Сокольники', 'lat': 55.789...
# 4     {'district': 'район Сокольники', 'lat': 55.789...
# ...                                                 ...
# 7692  {'district': 'Тверской район', 'lat': 55.77991...
# 7693  {'district': 'Пресненский район', 'lat': 55.74...
# 7694  {'district': 'Пресненский район', 'lat': 55.74...
# 7695  {'district': 'район Марьино', 'lat': 55.655882...
# 7696  {'district': 'район Митино', 'lat': 55.8509482...
#
#                     district         lat         lon            nearest_metro  \
# 0            район Хамовники  55.7430154  37.5969667    Москва, Кропоткинская
# 1     Лосиноостровский район  55.8811065  37.7007356       Москва, Медведково
# 2            Район не найден  55.1728895  37.1228243  Москва, Бунинская аллея
# 3           район Сокольники  55.7894219  37.6669807         Москва, Митьково
# 4           район Сокольники  55.7894219  37.6669807         Москва, Митьково
# ...                      ...         ...         ...                      ...
# 7692          Тверской район  55.7799144   37.605748   Москва, Новослободская
# 7693       Пресненский район  55.7488461  37.5353727      Москва, Москва-Сити
# 7694       Пресненский район  55.7456698  37.5364632      Москва, Москва-Сити
# 7695           район Марьино   55.655882  37.7630836    Москва, Братиславская
# 7696            район Митино  55.8509482  37.3658687           Москва, Митино
#
#               distance_km
# 0      0.4986147518013411
# 1      2.5324744833177726
# 2       47.59381546690349
# 3     0.48199635660262785
# 4     0.48199635660262785
# ...                   ...
# 7692  0.13147486674711037
# 7693  0.11512173600870493
# 7694   0.3289908236581064
# 7695   0.8895442902458882
# 7696   0.6184358944005334
#
# [7697 rows x 15 columns]
